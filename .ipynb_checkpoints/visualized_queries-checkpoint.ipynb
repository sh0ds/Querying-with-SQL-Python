# %%
import sqlite3
con = sqlite3.connect("Chinook_Sqlite.sqlite")
cur = con.cursor()

import pandas as pd

total_sales = cur.execute('''
    SELECT i.billingcountry, sum(total) AS 'TotalSales'
    FROM invoice AS i
    GROUP BY billingcountry
    ORDER BY totalsales DESC
    '''
)

country, total = total_sales.fetchone()
print(f"The highest grossing country is {country} with a total of {total}")
# Out:
# The highest grossing country is USA with a total of 523.06

# %%
import sqlite3
con = sqlite3.connect("Chinook_Sqlite.sqlite")
cur = con.cursor()

import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

top_artists = cur.execute('''
    SELECT t.Name, sum(il.UnitPrice), SUM(il.Quantity) AS TotalQuantitySold
    FROM Track as t
    LEFT JOIN InvoiceLine AS il ON t.TrackId = il.TrackId
    GROUP BY t.Name
    ORDER BY TotalQuantitySold DESC
    LIMIT 10;
    '''
                         )


df = pd.DataFrame(top_artists)
df.rename(columns={0: "Track", 1: "Revenue", 2: "Copies sold"})
print(df)
#ax = df.plot.bar(rot=0)
# Out:
#                            0     1  2
# 0                The Trooper  4.95  5
# 1                   Untitled  3.96  4
# 2    The Number Of The Beast  3.96  4
# 3        Sure Know Something  3.96  4
# 4       Hallowed Be Thy Name  3.96  4
# 5                   Eruption  3.96  4
# 6          Where Eagles Dare  2.97  3
# 7  Welcome Home (Sanitarium)  2.97  3
# 8             Sweetest Thing  2.97  3
# 9                  Surrender  2.97  3

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y)
plt.show()
